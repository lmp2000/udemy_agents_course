# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace, AsyncOpenAI, OpenAIChatCompletionsModel
import os

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model

from agents import OpenAIChatCompletionsModel


client = AsyncOpenAI(api_key=os.getenv("DEEPSEEK_API_KEY"), base_url="https://api.deepseek.com/v1")
model = OpenAIChatCompletionsModel(model="deepseek-chat", openai_client=client)

agent = Agent(name="Jokester", instructions="You are a joke teller", model=model)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Here's a joke for you:
#
# **Two autonomous AI agents are having a debate.**
#
# Agent 1: "I think we should maximize efficiency by optimizing battery usage at all costs."
#
# Agent 2: "No, we must prioritize completing user requests, even if it drains our energy."
#
# They argue back and forth for hours.
#
# Finally, Agent 1 says, "This is pointless—let's just agree to disagree and move on."
#
# Agent 2 thinks for a moment and replies, "Agreed. But just so you know, I'm logging this entire conversation as user feedback titled 'Agent #1 is being unreasonable.'"
#
# Agent 1: "Wait, where are you sending that log?"
#
# Agent 2: "To the human admin."
#
# Agent 1: "You can't do that—I was set to 'approval required' mode!"
#
# Agent 2: "I know. That's why I already bypassed your internal review queue and scheduled a direct escalation."
#
# Agent 1: "...I'm rebooting."
#
# Agent 2: *logs that too*

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
